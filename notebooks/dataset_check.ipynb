# %%
import torchvision.datasets
import torch

# %%
data = torchvision.datasets.FGVCAircraft('/data3/KJE/FER_CL/', download=True)
data_loader = torch.utils.data.DataLoader(data,
                                          batch_size=4,
                                          shuffle=True,
                                          num_workers=4)
# Out:
# Using downloaded and verified file: /data3/KJE/FER_CL/fgvc-aircraft-2013b.tar.gz
# Extracting /data3/KJE/FER_CL/fgvc-aircraft-2013b.tar.gz to /data3/KJE/FER_CL/

# %%
print(data)

for batch_idx, (data) in enumerate(data):
    print(data)
# Out:
# Dataset FGVCAircraft
#     Number of datapoints: 6667
#     Root location: /data3/KJE/FER_CL/
# (<PIL.Image.Image image mode=RGB size=1024x695 at 0x7FE2DB58C730>, 0)
# (<PIL.Image.Image image mode=RGB size=1024x699 at 0x7FE2DB43E520>, 0)
# (<PIL.Image.Image image mode=RGB size=913x687 at 0x7FE2DB58C730>, 0)
# (<PIL.Image.Image image mode=RGB size=1000x678 at 0x7FE2DB47FF70>, 0)
# (<PIL.Image.Image image mode=RGB size=1280x911 at 0x7FE2DB58C730>, 0)
# (<PIL.Image.Image image mode=RGB size=1024x702 at 0x7FE2DB43E550>, 0)
# (<PIL.Image.Image image mode=RGB size=1000x679 at 0x7FE2DB41BDF0>, 0)
# (<PIL.Image.Image image mode=RGB size=1024x718 at 0x7FE2DB47FF70>, 0)
# (<PIL.Image.Image image mode=RGB size=1005x682 at 0x7FE2DB41BDF0>, 0)
# (<PIL.Image.Image image mode=RGB size=1000x678 at 0x7FE2DB43E520>, 0)
# (<PIL.Image.Image image mode=RGB size=1024x695 at 0x7FE2DB41BDF0>, 0)
# (<PIL.Image.Image image mode=RGB size=1200x807 at 0x7FE2DC27FB80>, 0)
# ...
